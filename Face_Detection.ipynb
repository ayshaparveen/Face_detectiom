# %% [markdown]
# <a href="https://colab.research.google.com/github/ayshaparveen/Face_detection/blob/master/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=plt.imread("/content/gp1.png")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (385, 600, 3)

# %%
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
face_cascade = cv2.CascadeClassifier('/content/haarcascade_frontalface_alt.xml')

# %%
img = cv2.imread('/content/gp1.png')
faces = face_cascade.detectMultiScale(img)
print(faces)
# Out:
# [[232  31  41  41]
#  [347  49  31  31]
#  [132 119  45  45]
#  [325 129  48  48]
#  [400 129  50  50]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img)
